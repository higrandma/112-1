# %%
import pandas as pd
df = pd.read_csv('111年3月外籍結婚狀況.csv')
df.head()
# Out:
#   結婚人數按性別、婚姻類型及原屬國籍（地區）分 Unnamed: 1  \
# 0                    NaN        NaN
# 1                區  域  別         性別
# 2                    NaN        NaN
# 3                    NaN        NaN
# 4                    NaN        NaN
#
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                NaN        NaN        NaN
# 1  總                                             ...        NaN        NaN
# 2                                                NaN  本　　　國　　　籍        NaN
# 3                                                總　計        合　計        已設籍
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 118  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1        NaN        NaN        NaN        NaN        NaN  ...          NaN
# ...
